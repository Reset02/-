# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/Shareddrives/HW4_111061610/yolov7
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Shareddrives/HW4/yolov7

# %% [markdown]
# Download data from drive and put in {your_drive_path}/yolov7/data/
#
# [TODO]
# write two TODO functions in {your_drive_path}/yolov7/data/pre_process.py
#
# 1. split_train_val_path --> You need to split all image paths to train and validation in Q1, Q2, and Q3.
#
# 2. select_images --> You need to finish this function to chose better images in Q2 and Q3.

# %% [markdown]
# # **Q1測試:**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q1'
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q1')

# %%
# training command
# !python train.py --project runs/train/Q1 --name refine
# Out:
# 2023-11-27 16:23:54.691463: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 16:23:54.691518: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 16:23:54.691573: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 16:23:54.699799: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q1/refine/weights/best.pt" --project runs/test/Q1 --name refine
# Out:
# Namespace(weights=['./runs/train/Q1/refine/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q1', name='refine', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **Q2測試:**

# %% [markdown]
# # **方法1:**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 1
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=1)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_method_1
# Out:
# 2023-11-27 17:34:35.936929: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 17:34:35.936998: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 17:34:35.937039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 17:34:35.948610: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_method_1/weights/best.pt" --project runs/test/Q2 --name refine_method_1
# Out:
# Namespace(weights=['./runs/train/Q2/refine_method_1/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_method_1', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **方法2:**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 2
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=2)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_method_2
# Out:
# 2023-11-27 17:52:22.352595: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 17:52:22.352659: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 17:52:22.352698: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 17:52:22.368408: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_method_2/weights/best.pt" --project runs/test/Q2 --name refine_method_2
# Out:
# Namespace(weights=['./runs/train/Q2/refine_method_2/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_method_2', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **方法3:**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 3
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=3)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_method_3
# Out:
# 2023-11-27 18:18:47.099337: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-27 18:18:47.099401: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-27 18:18:47.099441: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-27 18:18:47.116911: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/test/Q2 --name refine_method_3
# Out:
# Namespace(weights=['./runs/train/Q2/refine_method_3/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_method_3', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **Q3測試:**

# %% [markdown]
# # **使用Q3 pseudo label**

# %%
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/170' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/173' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/398' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/410' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/495' --nosave --exist-ok
# !python detect.py --weight "./runs/train/Q2/refine_method_3/weights/best.pt" --project runs/detect/Q3 --name pseudo_label --save-txt --source './data/CityCam/Q3/511' --nosave --exist-ok
# Out:
# Namespace(weights=['./runs/train/Q2/refine_method_3/weights/best.pt'], source='./data/CityCam/Q3/170', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=True, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect/Q3', name='pseudo_label', exist_ok=True, no_trace=False)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **上面程式跑完輸出label.txt檔後，需要把相對應的txt檔複製到對應Q3資料合併，才可以跑下面的pseudo_label測試，例如:170相機所有的txt檔複製到Q3的170相機資料夾內**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q3_label' --method_number 3 --images_num 400
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q3_label', method_number=3, images_num=400)
# ...

# %%
# !python train.py --project runs/train/Q3_label --name refine_pseudo_label
# Out:
# 2023-11-28 13:09:19.428187: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 13:09:19.428267: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 13:09:19.428311: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 13:09:19.440606: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3_label/refine_pseudo_label/weights/best.pt" --project runs/test/Q3_label --name refine_pseudo_label
# Out:
# Namespace(weights=['./runs/train/Q3_label/refine_pseudo_label/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3_label', name='refine_pseudo_label', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **使用Q3 pseudo label 1400資料**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q3_label' --method_number 3 --images_num 1400
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q3_label', method_number=3, images_num=1400)
# ...

# %%
# !python train.py --project runs/train/Q3_label --name refine_pseudo_label_1400
# Out:
# 2023-11-28 16:18:44.228758: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 16:18:44.228813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 16:18:44.228853: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 16:18:44.237741: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q3_label/refine_pseudo_label_1400/weights/best.pt" --project runs/test/Q3_label --name refine_pseudo_label_1400
# Out:
# Namespace(weights=['./runs/train/Q3_label/refine_pseudo_label_1400/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q3_label', name='refine_pseudo_label_1400', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %% [markdown]
# # **測試freeze backbone**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 3
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=3)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_freeze_backbone --freeze 10
# Out:
# 2023-11-28 10:29:39.376400: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 10:29:39.376449: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 10:29:39.376483: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 10:29:39.384276: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_freeze_backbone/weights/best.pt" --project runs/test/Q2 --name refine_freeze_backbone
# Out:
# Namespace(weights=['./runs/train/Q2/refine_freeze_backbone/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_freeze_backbone', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **3層**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 3
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=3, images_num=200)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_freeze_backbone_3 --freeze 3
# Out:
# 2023-11-29 08:03:20.973670: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 08:03:20.973745: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 08:03:20.973787: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-29 08:03:20.985926: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_freeze_backbone_3/weights/best.pt" --project runs/test/Q2 --name refine_freeze_backbone_3
# Out:
# Namespace(weights=['./runs/train/Q2/refine_freeze_backbone_3/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_freeze_backbone_3', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...

# %% [markdown]
# # **測試 positive weight**

# %%
# pre-process data and generate training YAML file
# !python data/pre_process.py --data_folder './data/CityCam' --ques 'Q2' --method_number 3
# Out:
# Namespace(data_folder='./data/CityCam', ques='Q2', method_number=3)

# %%
# training command
# !python train.py --project runs/train/Q2 --name refine_positive_weight
# Out:
# 2023-11-28 10:51:39.725541: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 10:51:39.725597: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 10:51:39.725635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 10:51:39.733452: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# testing command
# !python test.py --verbose --show_div_cams --task test --weights "./runs/train/Q2/refine_positive_weight/weights/best.pt" --project runs/test/Q2 --name refine_positive_weight
# Out:
# Namespace(weights=['./runs/train/Q2/refine_positive_weight/weights/best.pt'], data='data/citycam.yaml', batch_size=32, img_size=640, conf_thres=0.001, iou_thres=0.65, task='test', device='', single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test/Q2', name='refine_positive_weight', exist_ok=False, no_trace=False, show_div_cams=True)
# YOLOR 🚀 2023-11-27 torch 2.1.0+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
# ...
